# %% [markdown]
# # Ecoli Dataset
# E. coli (Escherichia coli), is a type of bacteria that normally lives in our intestines. Mostly, this bacteria is not harmful  for our bodies, actually it supports and helps our digestive system.
#
# Refer to: https://archive.ics.uci.edu/ml/datasets/ecoli
#
# ## Main Goal
# Predicting the Localization Sites of Proteins.

# %% [markdown]
# ## Features
#
# <table>
#  <tr style='height:15.0pt'>
#   <td width=76 style='width:57.0pt;border:solid #5AA2AE 1.0pt;border-bottom:
#   solid #5AA2AE 1.5pt;padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><b><span style='font-family:"Times New Roman",serif;
#   color:black'>Name</span></b></p>
#   </td>
#   <td width=463 style='width:347.0pt;border-top:solid #5AA2AE 1.0pt;border-left:
#   none;border-bottom:solid #5AA2AE 1.5pt;border-right:solid #5AA2AE 1.0pt;
#   padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><b><span style='font-family:"Times New Roman",serif;
#   color:black'>Description </span></b></p>
#   </td>
#  </tr>
#  <tr style='height:15.6pt'>
#   <td width=76 style='width:57.0pt;border:solid #5AA2AE 1.0pt;border-top:none;
#   background:#EAF0F2;padding:0in 5.4pt 0in 5.4pt;height:15.6pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='font-family:"Times New Roman",serif;
#   color:black'>mcg</span></p>
#   </td>
#   <td width=463 style='width:347.0pt;border-top:none;border-left:none;
#   border-bottom:solid #5AA2AE 1.0pt;border-right:solid #5AA2AE 1.0pt;
#   background:#EAF0F2;padding:0in 5.4pt 0in 5.4pt;height:15.6pt'>
#   <p class=MsoNormal style='margin-bottom:0in;margin-bottom:.0001pt;line-height:
#   normal'><span style='font-family:"Times New Roman",serif;color:black'>McGeoch's
#   method for signal sequence recognition</span></p>
#   </td>
#  </tr>
#  <tr style='height:15.0pt'>
#   <td width=76 style='width:57.0pt;border:solid #5AA2AE 1.0pt;border-top:none;
#   padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='font-family:"Times New Roman",serif;
#   color:black'>gvh</span></p>
#   </td>
#   <td width=463 style='width:347.0pt;border-top:none;border-left:none;
#   border-bottom:solid #5AA2AE 1.0pt;border-right:solid #5AA2AE 1.0pt;
#   padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal style='margin-bottom:0in;margin-bottom:.0001pt;line-height:
#   normal'><span style='font-family:"Times New Roman",serif;color:black'>Heijne's
#   method for signal sequence recognition</span></p>
#   </td>
#  </tr>
#  <tr style='height:15.0pt'>
#   <td width=76 style='width:57.0pt;border:solid #5AA2AE 1.0pt;border-top:none;
#   background:#EAF0F2;padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='font-family:"Times New Roman",serif;
#   color:black'>lip</span></p>
#   </td>
#   <td width=463 style='width:347.0pt;border-top:none;border-left:none;
#   border-bottom:solid #5AA2AE 1.0pt;border-right:solid #5AA2AE 1.0pt;
#   background:#EAF0F2;padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal style='margin-bottom:0in;margin-bottom:.0001pt;line-height:
#   normal'><span style='font-family:"Times New Roman",serif;color:black'>Heijne's
#   Signal Peptidase II consensus sequence score. Binary attribute</span></p>
#   </td>
#  </tr>
#  <tr style='height:15.0pt'>
#   <td width=76 style='width:57.0pt;border:solid #5AA2AE 1.0pt;border-top:none;
#   padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='font-family:"Times New Roman",serif;
#   color:black'>chg</span></p>
#   </td>
#   <td width=463 style='width:347.0pt;border-top:none;border-left:none;
#   border-bottom:solid #5AA2AE 1.0pt;border-right:solid #5AA2AE 1.0pt;
#   padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal style='margin-bottom:0in;margin-bottom:.0001pt;line-height:
#   normal'><span style='font-family:"Times New Roman",serif;color:black'>Presence
#   of charge on N-terminus of predicted lipoproteins. Binary attribute.</span></p>
#   </td>
#  </tr>
#  <tr style='height:28.2pt'>
#   <td width=76 style='width:57.0pt;border:solid #5AA2AE 1.0pt;border-top:none;
#   background:#EAF0F2;padding:0in 5.4pt 0in 5.4pt;height:28.2pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='font-family:"Times New Roman",serif;
#   color:black'>aac</span></p>
#   </td>
#   <td width=463 style='width:347.0pt;border-top:none;border-left:none;
#   border-bottom:solid #5AA2AE 1.0pt;border-right:solid #5AA2AE 1.0pt;
#   background:#EAF0F2;padding:0in 5.4pt 0in 5.4pt;height:28.2pt'>
#   <p class=MsoNormal style='margin-bottom:0in;margin-bottom:.0001pt;line-height:
#   normal'><span style='font-family:"Times New Roman",serif;color:black'>score
#   of discriminant analysis of the amino acid content of outer membrane and
#   periplasmic proteins.</span></p>
#   </td>
#  </tr>
#  <tr style='height:15.0pt'>
#   <td width=76 style='width:57.0pt;border:solid #5AA2AE 1.0pt;border-top:none;
#   padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='font-family:"Times New Roman",serif;
#   color:black'>alm1</span></p>
#   </td>
#   <td width=463 style='width:347.0pt;border-top:none;border-left:none;
#   border-bottom:solid #5AA2AE 1.0pt;border-right:solid #5AA2AE 1.0pt;
#   padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal style='margin-bottom:0in;margin-bottom:.0001pt;line-height:
#   normal'><span style='font-family:"Times New Roman",serif;color:black'>score
#   of the ALOM membrane spanning region prediction program</span></p>
#   </td>
#  </tr>
#  <tr style='height:28.2pt'>
#   <td width=76 style='width:57.0pt;border:solid #5AA2AE 1.0pt;border-top:none;
#   background:#EAF0F2;padding:0in 5.4pt 0in 5.4pt;height:28.2pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='font-family:"Times New Roman",serif;
#   color:black'>alm2</span></p>
#   </td>
#   <td width=463 style='width:347.0pt;border-top:none;border-left:none;
#   border-bottom:solid #5AA2AE 1.0pt;border-right:solid #5AA2AE 1.0pt;
#   background:#EAF0F2;padding:0in 5.4pt 0in 5.4pt;height:28.2pt'>
#   <p class=MsoNormal style='margin-bottom:0in;margin-bottom:.0001pt;line-height:
#   normal'><span style='font-family:"Times New Roman",serif;color:black'>score
#   of ALOM program after excluding putative cleavable signal regions from the
#   sequence</span></p>
#   </td>
#  </tr>
# </table>

# %% [markdown]
# ## Classes (Labels)
#
# <table>
#  <tr style='height:15.0pt'>
#   <td width=343 style='width:257.0pt;border:solid #5AA2AE 1.0pt;border-bottom:
#   solid #5AA2AE 1.5pt;padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><b><span style='font-family:"Times New Roman",serif;
#   color:black'>Name</span></b></p>
#   </td>
#   <td width=141 style='width:106.0pt;border-top:solid #5AA2AE 1.0pt;border-left:
#   none;border-bottom:solid #5AA2AE 1.5pt;border-right:solid #5AA2AE 1.0pt;
#   padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><b><span style='font-family:"Times New Roman",serif;
#   color:black'>Corresponding Value </span></b></p>
#   </td>
#   <td width=120 style='width:1.25in;border-top:solid #5AA2AE 1.0pt;border-left:
#   none;border-bottom:solid #5AA2AE 1.5pt;border-right:solid #5AA2AE 1.0pt;
#   padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><b><span style='font-family:"Times New Roman",serif;
#   color:black'>Class Distribution</span></b></p>
#   </td>
#  </tr>
#  <tr style='height:15.6pt'>
#   <td width=343 style='width:257.0pt;border:solid #5AA2AE 1.0pt;border-top:
#   none;background:#EAF0F2;padding:0in 5.4pt 0in 5.4pt;height:15.6pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='color:black'>Cytoplasm
#   (cp)</span></p>
#   </td>
#   <td width=141 style='width:106.0pt;border-top:none;border-left:none;
#   border-bottom:solid #5AA2AE 1.0pt;border-right:solid #5AA2AE 1.0pt;
#   background:#EAF0F2;padding:0in 5.4pt 0in 5.4pt;height:15.6pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='font-family:"Times New Roman",serif;
#   color:black'>1</span></p>
#   </td>
#   <td width=120 style='width:1.25in;border-top:none;border-left:none;
#   border-bottom:solid #5AA2AE 1.0pt;border-right:solid #5AA2AE 1.0pt;
#   background:#EAF0F2;padding:0in 5.4pt 0in 5.4pt;height:15.6pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='font-family:"Times New Roman",serif;
#   color:black'>143</span></p>
#   </td>
#  </tr>
#  <tr style='height:15.0pt'>
#   <td width=343 style='width:257.0pt;border:solid #5AA2AE 1.0pt;border-top:
#   none;padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='color:black'>Inner
#   membrane without signal sequence (im)</span></p>
#   </td>
#   <td width=141 style='width:106.0pt;border-top:none;border-left:none;
#   border-bottom:solid #5AA2AE 1.0pt;border-right:solid #5AA2AE 1.0pt;
#   padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='font-family:"Times New Roman",serif;
#   color:black'>2</span></p>
#   </td>
#   <td width=120 style='width:1.25in;border-top:none;border-left:none;
#   border-bottom:solid #5AA2AE 1.0pt;border-right:solid #5AA2AE 1.0pt;
#   padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='font-family:"Times New Roman",serif;
#   color:black'>77</span></p>
#   </td>
#  </tr>
#  <tr style='height:15.0pt'>
#   <td width=343 style='width:257.0pt;border:solid #5AA2AE 1.0pt;border-top:
#   none;background:#EAF0F2;padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='color:black'>Periplasm
#   (pp)</span></p>
#   </td>
#   <td width=141 style='width:106.0pt;border-top:none;border-left:none;
#   border-bottom:solid #5AA2AE 1.0pt;border-right:solid #5AA2AE 1.0pt;
#   background:#EAF0F2;padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='font-family:"Times New Roman",serif;
#   color:black'>3</span></p>
#   </td>
#   <td width=120 style='width:1.25in;border-top:none;border-left:none;
#   border-bottom:solid #5AA2AE 1.0pt;border-right:solid #5AA2AE 1.0pt;
#   background:#EAF0F2;padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='font-family:"Times New Roman",serif;
#   color:black'>52</span></p>
#   </td>
#  </tr>
#  <tr style='height:15.0pt'>
#   <td width=343 style='width:257.0pt;border:solid #5AA2AE 1.0pt;border-top:
#   none;padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='color:black'>Inner
#   membrane with uncleavable signal sequence (imU)</span></p>
#   </td>
#   <td width=141 style='width:106.0pt;border-top:none;border-left:none;
#   border-bottom:solid #5AA2AE 1.0pt;border-right:solid #5AA2AE 1.0pt;
#   padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='font-family:"Times New Roman",serif;
#   color:black'>4</span></p>
#   </td>
#   <td width=120 style='width:1.25in;border-top:none;border-left:none;
#   border-bottom:solid #5AA2AE 1.0pt;border-right:solid #5AA2AE 1.0pt;
#   padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='font-family:"Times New Roman",serif;
#   color:black'>35</span></p>
#   </td>
#  </tr>
#  <tr style='height:15.0pt'>
#   <td width=343 style='width:257.0pt;border:solid #5AA2AE 1.0pt;border-top:
#   none;background:#EAF0F2;padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='color:black'>Outer
#   membrane (om)</span></p>
#   </td>
#   <td width=141 style='width:106.0pt;border-top:none;border-left:none;
#   border-bottom:solid #5AA2AE 1.0pt;border-right:solid #5AA2AE 1.0pt;
#   background:#EAF0F2;padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='font-family:"Times New Roman",serif;
#   color:black'>5</span></p>
#   </td>
#   <td width=120 style='width:1.25in;border-top:none;border-left:none;
#   border-bottom:solid #5AA2AE 1.0pt;border-right:solid #5AA2AE 1.0pt;
#   background:#EAF0F2;padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='font-family:"Times New Roman",serif;
#   color:black'>20</span></p>
#   </td>
#  </tr>
#  <tr style='height:15.0pt'>
#   <td width=343 style='width:257.0pt;border:solid #5AA2AE 1.0pt;border-top:
#   none;padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='color:black'>Outer
#   membrane lipoprotein (omL)</span></p>
#   </td>
#   <td width=141 style='width:106.0pt;border-top:none;border-left:none;
#   border-bottom:solid #5AA2AE 1.0pt;border-right:solid #5AA2AE 1.0pt;
#   padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='font-family:"Times New Roman",serif;
#   color:black'>6</span></p>
#   </td>
#   <td width=120 style='width:1.25in;border-top:none;border-left:none;
#   border-bottom:solid #5AA2AE 1.0pt;border-right:solid #5AA2AE 1.0pt;
#   padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='font-family:"Times New Roman",serif;
#   color:black'>5</span></p>
#   </td>
#  </tr>
#  <tr style='height:15.0pt'>
#   <td width=343 style='width:257.0pt;border:solid #5AA2AE 1.0pt;border-top:
#   none;background:#EAF0F2;padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='color:black'>Inner
#   membrane lipoprotein (imL)</span></p>
#   </td>
#   <td width=141 style='width:106.0pt;border-top:none;border-left:none;
#   border-bottom:solid #5AA2AE 1.0pt;border-right:solid #5AA2AE 1.0pt;
#   background:#EAF0F2;padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='font-family:"Times New Roman",serif;
#   color:black'>7</span></p>
#   </td>
#   <td width=120 style='width:1.25in;border-top:none;border-left:none;
#   border-bottom:solid #5AA2AE 1.0pt;border-right:solid #5AA2AE 1.0pt;
#   background:#EAF0F2;padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='font-family:"Times New Roman",serif;
#   color:black'>2</span></p>
#   </td>
#  </tr>
#  <tr style='height:15.0pt'>
#   <td width=343 style='width:257.0pt;border:solid #5AA2AE 1.0pt;border-top:
#   none;padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='color:black'>Inner
#   membrane with cleavable signal sequence (imS)</span></p>
#   </td>
#   <td width=141 style='width:106.0pt;border-top:none;border-left:none;
#   border-bottom:solid #5AA2AE 1.0pt;border-right:solid #5AA2AE 1.0pt;
#   padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='font-family:"Times New Roman",serif;
#   color:black'>8</span></p>
#   </td>
#   <td width=120 style='width:1.25in;border-top:none;border-left:none;
#   border-bottom:solid #5AA2AE 1.0pt;border-right:solid #5AA2AE 1.0pt;
#   padding:0in 5.4pt 0in 5.4pt;height:15.0pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><span style='font-family:"Times New Roman",serif;
#   color:black'>2</span></p>
#   </td>
#  </tr>
# </table>

# %% [markdown]
# ## Load Ecoli from CSV file
# The first step is to put the data in correct form in order to process it. So we will read the data from CSV file and assign the results into two arrays _data_ and _targets_. Also we will create an array containing a distinct values of our _labels_.

# %%
# %matplotlib inline

import numpy as np
from matplotlib import pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### 1. Loading labels

# %%
import csv

ecoli_csv = '../dataset/Ecoli/ecoli-dataset.csv';

ecoli_labels = np.genfromtxt(ecoli_csv, delimiter=',', usecols=(8), dtype=str)
  
labels = set(ecoli_labels)

print(labels)
# Out:
# {'imU', 'om', 'im', 'cp', 'imS', 'imL', 'omL', 'pp'}

# %% [markdown]
# ### 2. Loading Data and Targets
# _Note_: we ignore the first column in the dataset as it refers to _SequenceName_ in the origin database so it's not important in our process.

# %%
data = []
targets = []
features_names = ['mcg','gvh','lip','chg','aac','alm1','alm2']

with open(ecoli_csv, newline='') as csvfile:
    datasetreader = csv.reader(csvfile, delimiter=',')
    for row in datasetreader:
        if len(row) == 9:
            data.append([float(i) for i in row[1:8]])
            if row[8] == "cp":
                targets.append(1)
            elif row[8] == "im":
                targets.append(2)
            elif row[8] == "pp":
                targets.append(3)
            elif row[8] == "imU":
                targets.append(4)
            elif row[8] == "om":
                targets.append(5)
            elif row[8] == "omL":
                targets.append(6)
            elif row[8] == "imL":
                targets.append(7)
            else:
                targets.append(8)

data = np.array(data)
targets = np.array(targets)

# %% [markdown]
# ## Principle Component Analysis

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA

pca = PCA(n_components=2) 

ecoli_pca = pca.fit_transform(data)

plt.scatter(ecoli_pca[:, 0], ecoli_pca[:, 1], c=targets, edgecolor='none', alpha=0.8, cmap=plt.cm.get_cmap('nipy_spectral', 10))
plt.xlabel('component 1')
plt.ylabel('component 2')
plt.colorbar();

print(pca.components_)
# Out:
# [[ 0.34172063  0.09174926  0.01996988 -0.00097421  0.14711512  0.68991486
#    0.61382731]
#  [ 0.72982496  0.52879438  0.07250123  0.01168094  0.04804968 -0.07212754
#   -0.41812439]]

# %% [markdown]
# ### 3D Plotting
#
# It cannot work here as it's rendered in HTML, however if you try this code with another IDE such as PyCharm you will be able to see 3D plotting of the data and rotat in 3D space.

# %%
from ipywidgets import interact, fixed
from mpl_toolkits import mplot3d
from scipy import stats
from mlxtend.plotting import plot_decision_regions

X_train, X_test, Y_train, Y_test = train_test_split(data, ecoli_labels, test_size=0.20)
r = np.exp(-(X_train ** 2).sum(1))

def plot_3D(elev=30, azim=30, X=X_train, y=Y_train):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter3D(X[:, 0], X[:, 1], r, s=50, cmap=plt.cm.get_cmap('nipy_spectral', 10))
    ax.view_init(elev=elev, azim=azim)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('r')

interact(plot_3D, elev=[-90, 90], azip=(-180, 180),X=fixed(X_train), y=fixed(Y_train));
# Out:
# interactive(children=(Dropdown(description='elev', options=(-90, 90), value=-90), IntSlider(value=30, descript…

# %% [markdown]
# ### HeatMap using Seaborn library

# %%
import pandas as pd
comps = pd.DataFrame(pca.components_, columns = features_names)
comps

import seaborn as sb
sb.heatmap(comps,annot=True)

# %% [markdown]
# We can see that there is a strong negative correlation between _alm2_ and component1 while we see strong positive correlation between _mcg_ and component 1. Also strong positive correlation between _alm2_ and  component 0.

# %% [markdown]
# ### Features PairPlot using Seaborn

# %%
import pandas
features_names2 = ['num','mcg','gvh','lip','chg','aac','alm1','alm2','index']
data2 = pandas.read_csv(ecoli_csv, names=features_names2)

data2 = data2.drop('num', 1)

g =  sb.pairplot(data2, kind="scatter")
plt.show()

# %% [markdown]
# ## Multi-layer Perceptron Classifying (MLPClassifier)

# %%
X_train, X_test, Y_train,Y_test = train_test_split(data,targets,test_size=0.20)

Y_train_OneHot = np.eye(9)[Y_train]
Y_test_OneHot = np.eye(9)[Y_test]

clf = MLPClassifier(activation='relu', alpha=1, batch_size='auto', hidden_layer_sizes=(10,15), learning_rate='constant',
       learning_rate_init=0.001, max_iter=200, random_state= 1, shuffle=True, solver='lbfgs')

clf.fit(X_train, Y_train_OneHot)
print("Number of layers: ", clf.n_layers_)
print("Number of outputs: ", clf.n_outputs_)

h_train_pred = np.argmax(clf.predict(X_train), axis=1)
h_test_pred = np.argmax(clf.predict(X_test), axis=1)

plt.figure(figsize=(20,10))
plt.subplot(2, 2, 1)
plt.scatter(X_train[:,0], X_train[:,1], c=Y_train)
plt.title("Real labels [train]")
plt.subplot(2, 2, 2)
plt.scatter(X_train[:,0], X_train[:,1], c=h_train_pred)
plt.title("MLP [train]")
plt.subplot(2, 2, 3)
plt.scatter(X_test[:,0], X_test[:,1], c=Y_test)
plt.title("Real labels [test]")
plt.subplot(2, 2, 4)
plt.scatter(X_test[:,0], X_test[:,1], c=h_test_pred)
plt.title("MLP [test]");

print("Train accuracy: ", clf.score(X_train, Y_train_OneHot), " test accuracy:", clf.score(X_test,Y_test_OneHot))
# Out:
# Number of layers:  4
# Number of outputs:  9
# Train accuracy:  0.8582089552238806  test accuracy: 0.8088235294117647

# %% [markdown]
# ## Support Vector Machine
# Here we plot see how _rbf kernerl_ draw a line of the classfier that is build based on the two features (0 and 4).

# %%
from sklearn.svm import SVC
from mlxtend.plotting import plot_decision_regions

ecoli = np.array(data)
X_train, X_test, Y_train, Y_test = train_test_split(data, targets, test_size=0.20)


plt.figure(figsize=(20,20))
plt.subplot(2, 2, 1)
model = SVC(kernel='rbf', C=1e1)
X = X_train[:,[0,4]]
model.fit(X, Y_train)
plot_decision_regions(X=X, y=Y_train,clf=model,legend=1,res=0.02)
plt.title("rbf Kernel")
# Out:
# /home/tamer/Projects/breast-cancer-ecoli-classification/environment/py36/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# Text(0.5, 1.0, 'rbf Kernel')

# %% [markdown]
# ## Decision Tree Classification

# %%
from sklearn import tree

classifier = tree.DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
        max_features=None, max_leaf_nodes=None,
        min_impurity_decrease=0.0, min_impurity_split=None,
        min_samples_leaf=1, min_samples_split=2,
        min_weight_fraction_leaf=0.0, presort=False, random_state=None,
        splitter='best')
classifier.fit(X_train, Y_train)

print('Score: {}'.format(classifier.score(X_train, Y_train)))
print('Score: {}'.format(classifier.score(X_test, Y_test)))
# Out:
# Score: 1.0
# Score: 0.7647058823529411

# %% [markdown]
# ![title](ecoli_dt.png)
